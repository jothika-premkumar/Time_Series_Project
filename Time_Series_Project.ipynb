# %%
import pandas as pd
import statsmodels.api as sm
co2_data = sm.datasets.co2.load()
df = co2_data.data
df = df.rename(columns={'co2': 'electricity_consumption'})
df = df.sort_index()

# %%
print("DataFrame head after loading and setting index:")
print(df.head())
print("\nDataFrame info:")
print(df.info())
# Out:
# DataFrame head after loading and setting index:
#             electricity_consumption
# 1958-03-29                    316.1
# 1958-04-05                    317.3
# 1958-04-12                    317.6
# 1958-04-19                    317.5
# 1958-04-26                    316.4
#
# DataFrame info:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2284 entries, 1958-03-29 to 2001-12-29
# Freq: W-SAT
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   electricity_consumption  2225 non-null   float64
# dtypes: float64(1)
# memory usage: 35.7 KB
# None

# %%
print("Missing values before handling:")
print(df.isnull().sum())
df['electricity_consumption'] = df['electricity_consumption'].interpolate(method='linear')
print("\nMissing values after handling:")
print(df.isnull().sum())
print("\nDataFrame head after handling missing values:")
print(df.head())
print("DataFrame info after handling missing values:")
print(df.info())
# Out:
# Missing values before handling:
# electricity_consumption    59
# dtype: int64
#
# Missing values after handling:
# electricity_consumption    0
# dtype: int64
#
# DataFrame head after handling missing values:
#             electricity_consumption
# 1958-03-29                    316.1
# 1958-04-05                    317.3
# 1958-04-12                    317.6
# 1958-04-19                    317.5
# 1958-04-26                    316.4
# DataFrame info after handling missing values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2284 entries, 1958-03-29 to 2001-12-29
# Freq: W-SAT
# Data columns (total 1 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   electricity_consumption  2284 non-null   float64
# dtypes: float64(1)
# memory usage: 35.7 KB
# None

# %%
df['year'] = df.index.year
df['month_of_year'] = df.index.month
df['day_of_month'] = df.index.day
df['day_of_week'] = df.index.dayofweek

# %%
print("DataFrame head after adding time-based features:")
print(df.head())
print("\nDataFrame info after adding time-based features:")
print(df.info())
# Out:
# DataFrame head after adding time-based features:
#             electricity_consumption  year  month_of_year  day_of_month  \
# 1958-03-29                    316.1  1958              3            29
# 1958-04-05                    317.3  1958              4             5
# 1958-04-12                    317.6  1958              4            12
# 1958-04-19                    317.5  1958              4            19
# 1958-04-26                    316.4  1958              4            26
#
#             day_of_week
# 1958-03-29            5
# 1958-04-05            5
# 1958-04-12            5
# 1958-04-19            5
# 1958-04-26            5
#
# DataFrame info after adding time-based features:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2284 entries, 1958-03-29 to 2001-12-29
# Freq: W-SAT
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   electricity_consumption  2284 non-null   float64
#  1   year                     2284 non-null   int32
#  2   month_of_year            2284 non-null   int32
#  3   day_of_month             2284 non-null   int32
#  4   day_of_week              2284 non-null   int32
# dtypes: float64(1), int32(4)
# memory usage: 71.4 KB
# None

# %%
for i in range(1, 5):
    df[f'electricity_consumption_lag_{i}'] = df['electricity_consumption'].shift(i)
print("DataFrame head after adding lagged features:")
print(df.head())
print("\nDataFrame info after adding lagged features:")
print(df.info())
print("\nMissing values after adding lagged features (expected in first rows):")
print(df.isnull().sum())
# Out:
# DataFrame head after adding lagged features:
#             electricity_consumption  year  month_of_year  day_of_month  \
# 1958-03-29                    316.1  1958              3            29
# 1958-04-05                    317.3  1958              4             5
# 1958-04-12                    317.6  1958              4            12
# 1958-04-19                    317.5  1958              4            19
# 1958-04-26                    316.4  1958              4            26
#
#             day_of_week  electricity_consumption_lag_1  \
# 1958-03-29            5                            NaN
# 1958-04-05            5                          316.1
# 1958-04-12            5                          317.3
# 1958-04-19            5                          317.6
# 1958-04-26            5                          317.5
#
#             electricity_consumption_lag_2  electricity_consumption_lag_3  \
# 1958-03-29                            NaN                            NaN
# 1958-04-05                            NaN                            NaN
# 1958-04-12                          316.1                            NaN
# 1958-04-19                          317.3                          316.1
# 1958-04-26                          317.6                          317.3
#
#             electricity_consumption_lag_4
# 1958-03-29                            NaN
# 1958-04-05                            NaN
# 1958-04-12                            NaN
# 1958-04-19                            NaN
# 1958-04-26                          316.1
#
# DataFrame info after adding lagged features:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2284 entries, 1958-03-29 to 2001-12-29
# Freq: W-SAT
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   electricity_consumption        2284 non-null   float64
#  1   year                           2284 non-null   int32
#  2   month_of_year                  2284 non-null   int32
#  3   day_of_month                   2284 non-null   int32
#  4   day_of_week                    2284 non-null   int32
#  5   electricity_consumption_lag_1  2283 non-null   float64
#  6   electricity_consumption_lag_2  2282 non-null   float64
#  7   electricity_consumption_lag_3  2281 non-null   float64
#  8   electricity_consumption_lag_4  2280 non-null   float64
# dtypes: float64(5), int32(4)
# memory usage: 142.8 KB
# None
#
# Missing values after adding lagged features (expected in first rows):
# electricity_consumption          0
# year                             0
# month_of_year                    0
# day_of_month                     0
# day_of_week                      0
# electricity_consumption_lag_1    1
# electricity_consumption_lag_2    2
# electricity_consumption_lag_3    3
# electricity_consumption_lag_4    4
# dtype: int64

# %%
from sklearn.preprocessing import MinMaxScaler
numerical_features = [
    'electricity_consumption',
    'year',
    'month_of_year',
    'day_of_month',
    'day_of_week'
]
for i in range(1, 5):
    numerical_features.append(f'electricity_consumption_lag_{i}')
scaler = MinMaxScaler()
df[numerical_features] = scaler.fit_transform(df[numerical_features])
print("DataFrame head after normalization:")
print(df.head())
print("\nDataFrame info after normalization:")
print(df.info())
print("\nDescriptive statistics of normalized features:")
print(df[numerical_features].describe())
# Out:
# DataFrame head after normalization:
#             electricity_consumption  year  month_of_year  day_of_month  \
# 1958-03-29                 0.050903   0.0       0.181818      0.933333
# 1958-04-05                 0.070608   0.0       0.272727      0.133333
# 1958-04-12                 0.075534   0.0       0.272727      0.366667
# 1958-04-19                 0.073892   0.0       0.272727      0.600000
# 1958-04-26                 0.055829   0.0       0.272727      0.833333
#
#             day_of_week  electricity_consumption_lag_1  \
# 1958-03-29          0.0                            NaN
# 1958-04-05          0.0                       0.050903
# 1958-04-12          0.0                       0.070608
# 1958-04-19          0.0                       0.075534
# 1958-04-26          0.0                       0.073892
#
#             electricity_consumption_lag_2  electricity_consumption_lag_3  \
# 1958-03-29                            NaN                            NaN
# 1958-04-05                            NaN                            NaN
# 1958-04-12                       0.050903                            NaN
# 1958-04-19                       0.070608                       0.050903
# 1958-04-26                       0.075534                       0.070608
#
#             electricity_consumption_lag_4
# 1958-03-29                            NaN
# 1958-04-05                            NaN
# 1958-04-12                            NaN
# 1958-04-19                            NaN
# 1958-04-26                       0.050903
#
# DataFrame info after normalization:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2284 entries, 1958-03-29 to 2001-12-29
# Freq: W-SAT
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   electricity_consumption        2284 non-null   float64
#  1   year                           2284 non-null   float64
#  2   month_of_year                  2284 non-null   float64
#  3   day_of_month                   2284 non-null   float64
#  4   day_of_week                    2284 non-null   float64
#  5   electricity_consumption_lag_1  2283 non-null   float64
#  6   electricity_consumption_lag_2  2282 non-null   float64
#  7   electricity_consumption_lag_3  2281 non-null   float64
#  8   electricity_consumption_lag_4  2280 non-null   float64
# dtypes: float64(9)
# memory usage: 178.4 KB
# None
#
# Descriptive statistics of normalized features:
#        electricity_consumption         year  month_of_year  day_of_month  \
# count              2284.000000  2284.000000    2284.000000   2284.000000
# mean                  0.437644     0.502668       0.504219      0.491448
# std                   0.280847     0.293933       0.312947      0.293438
# min                   0.000000     0.000000       0.000000      0.000000
# 25%                   0.180213     0.255814       0.272727      0.233333
# 50%                   0.405583     0.511628       0.545455      0.500000
# 75%                   0.681445     0.767442       0.818182      0.733333
# max                   1.000000     1.000000       1.000000      1.000000
#
#        day_of_week  electricity_consumption_lag_1  \
# count       2284.0                    2283.000000
# mean           0.0                       0.437415
# std            0.0                       0.280695
# min            0.0                       0.000000
# 25%            0.0                       0.179803
# 50%            0.0                       0.405583
# 75%            0.0                       0.681445
# max            0.0                       1.000000
#
#        electricity_consumption_lag_2  electricity_consumption_lag_3  \
# count                    2282.000000                    2281.000000
# mean                        0.437187                       0.436959
# std                         0.280545                       0.280396
# min                         0.000000                       0.000000
# 25%                         0.179392                       0.178982
# 50%                         0.405583                       0.405583
# 75%                         0.681445                       0.681445
# max                         1.000000                       1.000000
#
#        electricity_consumption_lag_4
# count                    2280.000000
# mean                        0.436735
# std                         0.280252
# min                         0.000000
# 25%                         0.178982
# 50%                         0.405583
# 75%                         0.681445
# max                         1.000000

# %%
import numpy as np
target_variable = 'electricity_consumption'
data = df[[target_variable]].copy()
train_size = int(len(data) * 0.8)
train_data, test_data = data[0:train_size], data[train_size:len(data)]
print(f"Training data length: {len(train_data)}")
print(f"Testing data length: {len(test_data)}")
print("\nHead of training data:")
print(train_data.head())
print("\nHead of testing data:")
print(test_data.head())
# Out:
# Training data length: 1827
# Testing data length: 457
#
# Head of training data:
#             electricity_consumption
# 1958-03-29                 0.050903
# 1958-04-05                 0.070608
# 1958-04-12                 0.075534
# 1958-04-19                 0.073892
# 1958-04-26                 0.055829
#
# Head of testing data:
#             electricity_consumption
# 1993-04-03                 0.756979
# 1993-04-10                 0.752053
# 1993-04-17                 0.761905
# 1993-04-24                 0.771757
# 1993-05-01                 0.765189

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
order = (1, 1, 1)      
seasonal_order = (1, 1, 1, 52)
print(f"SARIMAX non-seasonal order: {order}")
print(f"SARIMAX seasonal order: {seasonal_order}")
sarimax_model = SARIMAX(train_data, order=order, seasonal_order=seasonal_order,
                        enforce_stationarity=False, enforce_invertibility=False)
sarimax_results = sarimax_model.fit(disp=False) 
print("\nSARIMAX Model Summary:")
print(sarimax_results.summary())
# Out:
# SARIMAX non-seasonal order: (1, 1, 1)
# SARIMAX seasonal order: (1, 1, 1, 52)
#
# SARIMAX Model Summary:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:            electricity_consumption   No. Observations:                 1827
# Model:             SARIMAX(1, 1, 1)x(1, 1, 1, 52)   Log Likelihood                6287.847
# Date:                            Fri, 21 Nov 2025   AIC                         -12565.693
# Time:                                    00:26:58   BIC                         -12538.443
# Sample:                                03-29-1958   HQIC                        -12555.611
#                                      - 03-27-1993
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.3164      0.034      9.275      0.000       0.250       0.383
# ma.L1         -0.7842      0.024    -33.218      0.000      -0.831      -0.738
# ar.S.L52      -0.2178      0.027     -8.134      0.000      -0.270      -0.165
# ma.S.L52      -0.7482      0.021    -36.442      0.000      -0.788      -0.708
# sigma2      3.812e-05   1.22e-06     31.369      0.000    3.57e-05    4.05e-05
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):                24.34
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.14   Skew:                            -0.20
# Prob(H) (two-sided):                  0.11   Kurtosis:                         3.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
import matplotlib.pyplot as plt
sarimax_train_predictions = sarimax_results.get_prediction(start=0, end=len(train_data)-1)
sarimax_train_pred_mean = sarimax_train_predictions.predicted_mean
sarimax_test_forecast = sarimax_results.get_forecast(steps=len(test_data))
sarimax_test_forecast_mean = sarimax_test_forecast.predicted_mean
print("SARIMAX in-sample predictions head:")
print(sarimax_train_pred_mean.head())
print("\nSARIMAX out-of-sample forecasts head:")
print(sarimax_test_forecast_mean.head())
plt.figure(figsize=(15, 6))
plt.plot(train_data.index, train_data[target_variable], label='Training Data')
plt.plot(test_data.index, test_data[target_variable], label='Actual Test Data')
plt.plot(sarimax_test_forecast_mean.index, sarimax_test_forecast_mean, color='red', label='SARIMAX Forecast')
plt.title('SARIMAX Model Forecast vs Actuals')
plt.xlabel('Date')
plt.ylabel('Electricity Consumption (Normalized)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# SARIMAX in-sample predictions head:
# 1958-03-29    0.000000
# 1958-04-05    0.056272
# 1958-04-12    0.074647
# 1958-04-19    0.076956
# 1958-04-26    0.073845
# Freq: W-SAT, Name: predicted_mean, dtype: float64
#
# SARIMAX out-of-sample forecasts head:
# 1993-04-03    0.756902
# 1993-04-10    0.757111
# 1993-04-17    0.769368
# 1993-04-24    0.767860
# 1993-05-01    0.770945
# Freq: W-SAT, Name: predicted_mean, dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
rmse = np.sqrt(mean_squared_error(test_data[target_variable], sarimax_test_forecast_mean))
mae = mean_absolute_error(test_data[target_variable], sarimax_test_forecast_mean)
print(f"\nSARIMAX Model Performance on Test Set:")
print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")
# Out:
# SARIMAX Model Performance on Test Set:
# RMSE: 0.0485
# MAE: 0.0415

# %%
df_cleaned = df.dropna()
print("DataFrame head after dropping NaN values:")
print(df_cleaned.head())
print("\nDataFrame info after dropping NaN values:")
print(df_cleaned.info())
print("\nMissing values after dropping NaN values:")
print(df_cleaned.isnull().sum())
# Out:
# DataFrame head after dropping NaN values:
#             electricity_consumption  year  month_of_year  day_of_month  \
# 1958-04-26                 0.055829   0.0       0.272727      0.833333
# 1958-05-03                 0.064039   0.0       0.363636      0.066667
# 1958-05-10                 0.068966   0.0       0.363636      0.300000
# 1958-05-17                 0.073892   0.0       0.363636      0.533333
# 1958-05-24                 0.080460   0.0       0.363636      0.766667
#
#             day_of_week  electricity_consumption_lag_1  \
# 1958-04-26          0.0                       0.073892
# 1958-05-03          0.0                       0.055829
# 1958-05-10          0.0                       0.064039
# 1958-05-17          0.0                       0.068966
# 1958-05-24          0.0                       0.073892
#
#             electricity_consumption_lag_2  electricity_consumption_lag_3  \
# 1958-04-26                       0.075534                       0.070608
# 1958-05-03                       0.073892                       0.075534
# 1958-05-10                       0.055829                       0.073892
# 1958-05-17                       0.064039                       0.055829
# 1958-05-24                       0.068966                       0.064039
#
#             electricity_consumption_lag_4
# 1958-04-26                       0.050903
# 1958-05-03                       0.070608
# 1958-05-10                       0.075534
# 1958-05-17                       0.073892
# 1958-05-24                       0.055829
#
# DataFrame info after dropping NaN values:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2280 entries, 1958-04-26 to 2001-12-29
# Freq: W-SAT
# Data columns (total 9 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   electricity_consumption        2280 non-null   float64
#  1   year                           2280 non-null   float64
#  2   month_of_year                  2280 non-null   float64
#  3   day_of_month                   2280 non-null   float64
#  4   day_of_week                    2280 non-null   float64
#  5   electricity_consumption_lag_1  2280 non-null   float64
#  6   electricity_consumption_lag_2  2280 non-null   float64
#  7   electricity_consumption_lag_3  2280 non-null   float64
#  8   electricity_consumption_lag_4  2280 non-null   float64
# dtypes: float64(9)
# memory usage: 178.1 KB
# None
#
# Missing values after dropping NaN values:
# electricity_consumption          0
# year                             0
# month_of_year                    0
# day_of_month                     0
# day_of_week                      0
# electricity_consumption_lag_1    0
# electricity_consumption_lag_2    0
# electricity_consumption_lag_3    0
# electricity_consumption_lag_4    0
# dtype: int64

# %%
import numpy as np
sequence_length = 20
features = df_cleaned.drop(columns=['electricity_consumption']).values
target = df_cleaned['electricity_consumption'].values
X, y = [], []
for i in range(sequence_length, len(df_cleaned)):
    X.append(df_cleaned.iloc[i-sequence_length : i].values)
    y.append(df_cleaned.iloc[i]['electricity_consumption'])
X = np.array(X)
y = np.array(y)
print(f"Shape of X (input sequences): {X.shape}")
print(f"Shape of y (target values): {y.shape}")
# Out:
# Shape of X (input sequences): (2260, 20, 9)
# Shape of y (target values): (2260,)

# %%
import numpy as np
train_split = int(0.7 * len(X))
val_split = int(0.1 * len(X))
test_split = len(X) - train_split - val_split
X_train, y_train = X[0:train_split], y[0:train_split]
X_val, y_val = X[train_split:train_split + val_split], y[train_split:train_split + val_split]
X_test, y_test = X[train_split + val_split:], y[train_split + val_split:]
print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of X_val: {X_val.shape}")
print(f"Shape of y_val: {y_val.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (1582, 20, 9)
# Shape of y_train: (1582,)
# Shape of X_val: (226, 20, 9)
# Shape of y_val: (226,)
# Shape of X_test: (452, 20, 9)
# Shape of y_test: (452,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
print("TensorFlow and Keras libraries imported.")
# Out:
# TensorFlow and Keras libraries imported.

# %%
from tensorflow.keras.optimizers import Adam
model = Sequential()
model.add(LSTM(units=50, activation='relu', input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(units=1))
optimizer = Adam(learning_rate=0.001)
model.compile(optimizer=optimizer, loss='mean_squared_error', metrics=['mean_absolute_error'])
print("LSTM Model Summary:")
model.summary()
# Out:
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# LSTM Model Summary:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        12,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,051 (47.07 KB)
#  Trainable params: 12,051 (47.07 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs = 50
batch_size = 32
history = model.fit(
    X_train, y_train,
    epochs=epochs,
    batch_size=batch_size,
    validation_data=(X_val, y_val),
    verbose=1
)
print(f"\nModel training complete after {epochs} epochs.")
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 6s 27ms/step - loss: 0.0049 - mean_absolute_error: 0.0455 - val_loss: 9.3892e-04 - val_mean_absolute_error: 0.0233
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 4.1238e-04 - mean_absolute_error: 0.0164 - val_loss: 6.5667e-04 - val_mean_absolute_error: 0.0216
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.9932e-04 - mean_absolute_error: 0.0141 - val_loss: 4.4035e-04 - val_mean_absolute_error: 0.0170
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.9687e-04 - mean_absolute_error: 0.0112 - val_loss: 2.9722e-04 - val_mean_absolute_error: 0.0135
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3744e-04 - mean_absolute_error: 0.0093 - val_loss: 2.5227e-04 - val_mean_absolute_error: 0.0122
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1920e-04 - mean_absolute_error: 0.0086 - val_loss: 1.6630e-04 - val_mean_absolute_error: 0.0104
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 9.7147e-05 - mean_absolute_error: 0.0078 - val_loss: 2.1581e-04 - val_mean_absolute_error: 0.0114
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 9.0332e-05 - mean_absolute_error: 0.0075 - val_loss: 1.5155e-04 - val_mean_absolute_error: 0.0103
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.4111e-05 - mean_absolute_error: 0.0073 - val_loss: 2.1599e-04 - val_mean_absolute_error: 0.0118
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 7.6017e-05 - mean_absolute_error: 0.0069 - val_loss: 1.2677e-04 - val_mean_absolute_error: 0.0091
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.1991e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1477e-04 - val_mean_absolute_error: 0.0147
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7829e-05 - mean_absolute_error: 0.0065 - val_loss: 1.1786e-04 - val_mean_absolute_error: 0.0087
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 8.1746e-05 - mean_absolute_error: 0.0072 - val_loss: 1.1262e-04 - val_mean_absolute_error: 0.0085
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 7.2025e-05 - mean_absolute_error: 0.0067 - val_loss: 3.0519e-04 - val_mean_absolute_error: 0.0148
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.5198e-05 - mean_absolute_error: 0.0064 - val_loss: 1.3666e-04 - val_mean_absolute_error: 0.0094
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7157e-05 - mean_absolute_error: 0.0060 - val_loss: 1.1643e-04 - val_mean_absolute_error: 0.0087
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.3364e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3320e-04 - val_mean_absolute_error: 0.0093
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2145e-05 - mean_absolute_error: 0.0058 - val_loss: 1.3903e-04 - val_mean_absolute_error: 0.0096
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.3366e-05 - mean_absolute_error: 0.0058 - val_loss: 2.6597e-04 - val_mean_absolute_error: 0.0138
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.2739e-05 - mean_absolute_error: 0.0058 - val_loss: 1.1137e-04 - val_mean_absolute_error: 0.0084
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.9409e-05 - mean_absolute_error: 0.0056 - val_loss: 2.9395e-04 - val_mean_absolute_error: 0.0147
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 5.9462e-05 - mean_absolute_error: 0.0062 - val_loss: 1.9225e-04 - val_mean_absolute_error: 0.0114
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9234e-05 - mean_absolute_error: 0.0056 - val_loss: 1.1405e-04 - val_mean_absolute_error: 0.0085
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 5.0161e-05 - mean_absolute_error: 0.0056 - val_loss: 1.3278e-04 - val_mean_absolute_error: 0.0093
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1407e-05 - mean_absolute_error: 0.0057 - val_loss: 1.3846e-04 - val_mean_absolute_error: 0.0095
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.7518e-05 - mean_absolute_error: 0.0055 - val_loss: 1.4868e-04 - val_mean_absolute_error: 0.0098
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.8622e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0051e-04 - val_mean_absolute_error: 0.0080
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6551e-05 - mean_absolute_error: 0.0060 - val_loss: 1.4333e-04 - val_mean_absolute_error: 0.0096
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 4.8046e-05 - mean_absolute_error: 0.0055 - val_loss: 2.2308e-04 - val_mean_absolute_error: 0.0123
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.8547e-05 - mean_absolute_error: 0.0061 - val_loss: 8.4828e-05 - val_mean_absolute_error: 0.0073
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.8627e-05 - mean_absolute_error: 0.0055 - val_loss: 1.9862e-04 - val_mean_absolute_error: 0.0117
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.5699e-05 - mean_absolute_error: 0.0054 - val_loss: 9.1426e-05 - val_mean_absolute_error: 0.0077
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.6337e-05 - mean_absolute_error: 0.0054 - val_loss: 1.3262e-04 - val_mean_absolute_error: 0.0092
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.5530e-05 - mean_absolute_error: 0.0053 - val_loss: 2.3148e-04 - val_mean_absolute_error: 0.0127
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.3675e-05 - mean_absolute_error: 0.0052 - val_loss: 1.1340e-04 - val_mean_absolute_error: 0.0085
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4500e-05 - mean_absolute_error: 0.0053 - val_loss: 1.6155e-04 - val_mean_absolute_error: 0.0103
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.3968e-05 - mean_absolute_error: 0.0052 - val_loss: 2.9504e-04 - val_mean_absolute_error: 0.0146
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4720e-05 - mean_absolute_error: 0.0053 - val_loss: 2.0597e-04 - val_mean_absolute_error: 0.0119
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.5127e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0913e-04 - val_mean_absolute_error: 0.0083
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.9253e-05 - mean_absolute_error: 0.0061 - val_loss: 9.4845e-05 - val_mean_absolute_error: 0.0078
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2352e-05 - mean_absolute_error: 0.0056 - val_loss: 9.7542e-05 - val_mean_absolute_error: 0.0079
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 4.4377e-05 - mean_absolute_error: 0.0053 - val_loss: 1.3476e-04 - val_mean_absolute_error: 0.0094
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4888e-05 - mean_absolute_error: 0.0053 - val_loss: 2.6995e-04 - val_mean_absolute_error: 0.0142
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.2009e-05 - mean_absolute_error: 0.0051 - val_loss: 8.4997e-05 - val_mean_absolute_error: 0.0073
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0493e-05 - mean_absolute_error: 0.0056 - val_loss: 8.8474e-05 - val_mean_absolute_error: 0.0075
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.1636e-05 - mean_absolute_error: 0.0057 - val_loss: 3.8344e-04 - val_mean_absolute_error: 0.0173
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.8456e-05 - mean_absolute_error: 0.0062 - val_loss: 2.9743e-04 - val_mean_absolute_error: 0.0149
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.5173e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4542e-04 - val_mean_absolute_error: 0.0097
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.0811e-05 - mean_absolute_error: 0.0057 - val_loss: 1.8574e-04 - val_mean_absolute_error: 0.0113
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 4.4904e-05 - mean_absolute_error: 0.0053 - val_loss: 1.1735e-04 - val_mean_absolute_error: 0.0086
#
# Model training complete after 50 epochs.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
lstm_predictions = model.predict(X_test)
lstm_predictions_1d = lstm_predictions.flatten()
rmse_lstm = np.sqrt(mean_squared_error(y_test, lstm_predictions_1d))
mae_lstm = mean_absolute_error(y_test, lstm_predictions_1d)
print(f"\nLSTM Model Performance on Test Set:")
print(f"RMSE: {rmse_lstm:.4f}")
print(f"MAE: {mae_lstm:.4f}")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
#
# LSTM Model Performance on Test Set:
# RMSE: 0.0280
# MAE: 0.0255

# %%
import numpy as np
lstm_units_range = [50, 75, 100] 
learning_rates_range = [0.01, 0.001, 0.0001] 
sequence_lengths_range = [10, 20, 30] 
results = []
print(f"Hyperparameter ranges defined:")
print(f"LSTM Units: {lstm_units_range}")
print(f"Learning Rates: {learning_rates_range}")
print(f"Sequence Lengths: {sequence_lengths_range}")
# Out:
# Hyperparameter ranges defined:
# LSTM Units: [50, 75, 100]
# Learning Rates: [0.01, 0.001, 0.0001]
# Sequence Lengths: [10, 20, 30]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
best_rmse = float('inf')
best_params = {}
for lstm_units in lstm_units_range:
    for learning_rate in learning_rates_range:
        for current_sequence_length in sequence_lengths_range:
            print(f"\n--- Tuning: LSTM Units={lstm_units}, Learning Rate={learning_rate}, Sequence Length={current_sequence_length} ---")
            X_temp, y_temp = [], []
            features_temp = df_cleaned.drop(columns=['electricity_consumption']).values
            target_temp = df_cleaned['electricity_consumption'].values
            for i in range(current_sequence_length, len(df_cleaned)):
                X_temp.append(df_cleaned.iloc[i-current_sequence_length : i].values)
                y_temp.append(df_cleaned.iloc[i]['electricity_consumption'])
            X_temp = np.array(X_temp)
            y_temp = np.array(y_temp)
            train_split = int(0.7 * len(X_temp))
            val_split = int(0.1 * len(X_temp))
            current_test_split_len = len(X_temp) - train_split - val_split
            if current_test_split_len <= 0:
                print(f"Skipping combination (seq_len={current_sequence_length}) due to insufficient data for test set.")
                continue
            X_train_tuned, y_train_tuned = X_temp[0:train_split], y_temp[0:train_split]
            X_val_tuned, y_val_tuned = X_temp[train_split:train_split + val_split], y_temp[train_split:train_split + val_split]
            X_test_tuned, y_test_tuned = X_temp[train_split + val_split:], y_temp[train_split + val_split:]
            num_features = X_train_tuned.shape[2]
            model_tuned = Sequential()
            model_tuned.add(LSTM(units=lstm_units, activation='relu', input_shape=(current_sequence_length, num_features)))
            model_tuned.add(Dense(units=1))
            optimizer_tuned = Adam(learning_rate=learning_rate)
            model_tuned.compile(optimizer=optimizer_tuned, loss='mean_squared_error', metrics=['mean_absolute_error'])
            history_tuned = model_tuned.fit(
                X_train_tuned, y_train_tuned,
                epochs=20,
                batch_size=32,
                validation_data=(X_val_tuned, y_val_tuned),
                verbose=0 
            )
            lstm_predictions_tuned = model_tuned.predict(X_test_tuned, verbose=0).flatten()
            rmse_tuned = np.sqrt(mean_squared_error(y_test_tuned, lstm_predictions_tuned))
            mae_tuned = mean_absolute_error(y_test_tuned, lstm_predictions_tuned)
            print(f"   Test RMSE: {rmse_tuned:.4f}, Test MAE: {mae_tuned:.4f}")
            results.append({
                'lstm_units': lstm_units,
                'learning_rate': learning_rate,
                'sequence_length': current_sequence_length,
                'rmse': rmse_tuned,
                'mae': mae_tuned
            })
            if rmse_tuned < best_rmse:
                best_rmse = rmse_tuned
                best_params = {
                    'lstm_units': lstm_units,
                    'learning_rate': learning_rate,
                    'sequence_length': current_sequence_length,
                    'rmse': best_rmse,
                    'mae': mae_tuned
                }
# Out:
# --- Tuning: LSTM Units=50, Learning Rate=0.01, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0124, Test MAE: 0.0099
#
# --- Tuning: LSTM Units=50, Learning Rate=0.01, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0156, Test MAE: 0.0127
#
# --- Tuning: LSTM Units=50, Learning Rate=0.01, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0137, Test MAE: 0.0115
#
# --- Tuning: LSTM Units=50, Learning Rate=0.001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0298, Test MAE: 0.0260
#
# --- Tuning: LSTM Units=50, Learning Rate=0.001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0213, Test MAE: 0.0177
#
# --- Tuning: LSTM Units=50, Learning Rate=0.001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0419, Test MAE: 0.0339
#
# --- Tuning: LSTM Units=50, Learning Rate=0.0001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0966, Test MAE: 0.0852
#
# --- Tuning: LSTM Units=50, Learning Rate=0.0001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0533, Test MAE: 0.0461
#
# --- Tuning: LSTM Units=50, Learning Rate=0.0001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.1548, Test MAE: 0.1186
#
# --- Tuning: LSTM Units=75, Learning Rate=0.01, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0290, Test MAE: 0.0269
#
# --- Tuning: LSTM Units=75, Learning Rate=0.01, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0319, Test MAE: 0.0296
#
# --- Tuning: LSTM Units=75, Learning Rate=0.01, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0125, Test MAE: 0.0101
#
# --- Tuning: LSTM Units=75, Learning Rate=0.001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0418, Test MAE: 0.0377
#
# --- Tuning: LSTM Units=75, Learning Rate=0.001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0413, Test MAE: 0.0384
#
# --- Tuning: LSTM Units=75, Learning Rate=0.001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0196, Test MAE: 0.0170
#
# --- Tuning: LSTM Units=75, Learning Rate=0.0001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0575, Test MAE: 0.0509
#
# --- Tuning: LSTM Units=75, Learning Rate=0.0001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0554, Test MAE: 0.0447
#
# --- Tuning: LSTM Units=75, Learning Rate=0.0001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.1037, Test MAE: 0.0914
#
# --- Tuning: LSTM Units=100, Learning Rate=0.01, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0096, Test MAE: 0.0078
#
# --- Tuning: LSTM Units=100, Learning Rate=0.01, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0306, Test MAE: 0.0291
#
# --- Tuning: LSTM Units=100, Learning Rate=0.01, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0200, Test MAE: 0.0181
#
# --- Tuning: LSTM Units=100, Learning Rate=0.001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0261, Test MAE: 0.0224
#
# --- Tuning: LSTM Units=100, Learning Rate=0.001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0296, Test MAE: 0.0262
#
# --- Tuning: LSTM Units=100, Learning Rate=0.001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0462, Test MAE: 0.0440
#
# --- Tuning: LSTM Units=100, Learning Rate=0.0001, Sequence Length=10 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0305, Test MAE: 0.0250
#
# --- Tuning: LSTM Units=100, Learning Rate=0.0001, Sequence Length=20 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0279, Test MAE: 0.0228
#
# --- Tuning: LSTM Units=100, Learning Rate=0.0001, Sequence Length=30 ---
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
#    Test RMSE: 0.0528, Test MAE: 0.0420

# %%
print("\n--- Hyperparameter Tuning Results ---")
if best_params:
    print(f"Best Hyperparameters: LSTM Units = {best_params['lstm_units']}, Learning Rate = {best_params['learning_rate']}, Sequence Length = {best_params['sequence_length']}")
    print(f"Best RMSE: {best_params['rmse']:.4f}")
    print(f"Best MAE: {best_params['mae']:.4f}")
else:
    print("No best parameters found. Tuning might not have completed successfully or no valid combinations were tested.")
# Out:
# --- Hyperparameter Tuning Results ---
# Best Hyperparameters: LSTM Units = 100, Learning Rate = 0.01, Sequence Length = 10
# Best RMSE: 0.0096
# Best MAE: 0.0078

# %%
import numpy as np
optimal_sequence_length = best_params['sequence_length']
features_final = df_cleaned.drop(columns=['electricity_consumption']).values
target_final = df_cleaned['electricity_consumption'].values
X_final, y_final = [], []
for i in range(optimal_sequence_length, len(df_cleaned)):
    X_final.append(df_cleaned.iloc[i-optimal_sequence_length : i].values)
    y_final.append(df_cleaned.iloc[i]['electricity_consumption'])
X_final = np.array(X_final)
y_final = np.array(y_final)
print(f"Re-created X_final shape with optimal sequence length ({optimal_sequence_length}): {X_final.shape}")
print(f"Re-created y_final shape with optimal sequence length ({optimal_sequence_length}): {y_final.shape}")
# Out:
# Re-created X_final shape with optimal sequence length (10): (2270, 10, 9)
# Re-created y_final shape with optimal sequence length (10): (2270,)

# %%
import numpy as np
train_split_final = int(0.7 * len(X_final))
val_split_final = int(0.1 * len(X_final))
X_train_final, y_train_final = X_final[0:train_split_final], y_final[0:train_split_final]
X_val_final, y_val_final = X_final[train_split_final:train_split_final + val_split_final], y_final[train_split_final:train_split_final + val_split_final]
X_test_final, y_test_final = X_final[train_split_final + val_split_final:], y_final[train_split_final + val_split_final:]
print(f"Shape of X_train_final: {X_train_final.shape}")
print(f"Shape of y_train_final: {y_train_final.shape}")
print(f"Shape of X_val_final: {X_val_final.shape}")
print(f"Shape of y_val_final: {y_val_final.shape}")
print(f"Shape of X_test_final: {X_test_final.shape}")
print(f"Shape of y_test_final: {y_test_final.shape}")
# Out:
# Shape of X_train_final: (1589, 10, 9)
# Shape of y_train_final: (1589,)
# Shape of X_val_final: (227, 10, 9)
# Shape of y_val_final: (227,)
# Shape of X_test_final: (454, 10, 9)
# Shape of y_test_final: (454,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam
optimal_lstm_units = best_params['lstm_units']
optimal_learning_rate = best_params['learning_rate']
model_final = Sequential()
model_final.add(LSTM(units=optimal_lstm_units, activation='relu', input_shape=(X_train_final.shape[1], X_train_final.shape[2])))
model_final.add(Dense(units=1)) 
optimizer_final = Adam(learning_rate=optimal_learning_rate)
model_final.compile(optimizer=optimizer_final, loss='mean_squared_error', metrics=['mean_absolute_error'])
print(f"Final LSTM Model configured with units={optimal_lstm_units}, learning_rate={optimal_learning_rate}")
print("Final LSTM Model Summary:")
model_final.summary()
# Out:
# Final LSTM Model configured with units=100, learning_rate=0.01
# Final LSTM Model Summary:
# C:\Users\pjoth\AppData\Roaming\Python\Python311\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_29"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_28 (LSTM)                  │ (None, 100)            │        44,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_28 (Dense)                │ (None, 1)              │           101 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,101 (172.27 KB)
#  Trainable params: 44,101 (172.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
epochs_final = 50 
batch_size_final = 32
history_final = model_final.fit(
    X_train_final, y_train_final,
    epochs=epochs_final,
    batch_size=batch_size_final,
    validation_data=(X_val_final, y_val_final),
    verbose=1
)
print(f"\nFinal model training complete after {epochs_final} epochs.")
# Out:
# Epoch 1/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 5s 30ms/step - loss: 0.0071 - mean_absolute_error: 0.0473 - val_loss: 8.0613e-04 - val_mean_absolute_error: 0.0233
# Epoch 2/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9889e-04 - mean_absolute_error: 0.0160 - val_loss: 3.7245e-04 - val_mean_absolute_error: 0.0156
# Epoch 3/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.8701e-04 - mean_absolute_error: 0.0139 - val_loss: 3.6667e-04 - val_mean_absolute_error: 0.0155
# Epoch 4/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.4560e-04 - mean_absolute_error: 0.0127 - val_loss: 2.9696e-04 - val_mean_absolute_error: 0.0142
# Epoch 5/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.0634e-04 - mean_absolute_error: 0.0115 - val_loss: 3.4621e-04 - val_mean_absolute_error: 0.0157
# Epoch 6/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.9552e-04 - mean_absolute_error: 0.0110 - val_loss: 1.5119e-04 - val_mean_absolute_error: 0.0101
# Epoch 7/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1294e-04 - mean_absolute_error: 0.0085 - val_loss: 8.7221e-04 - val_mean_absolute_error: 0.0278
# Epoch 8/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 9.8470e-05 - mean_absolute_error: 0.0079 - val_loss: 2.0002e-04 - val_mean_absolute_error: 0.0118
# Epoch 9/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.0835e-05 - mean_absolute_error: 0.0061 - val_loss: 1.3663e-04 - val_mean_absolute_error: 0.0096
# Epoch 10/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.3047e-05 - mean_absolute_error: 0.0062 - val_loss: 8.1832e-05 - val_mean_absolute_error: 0.0073
# Epoch 11/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 5.8856e-05 - mean_absolute_error: 0.0061 - val_loss: 9.7211e-05 - val_mean_absolute_error: 0.0080
# Epoch 12/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.4274e-05 - mean_absolute_error: 0.0058 - val_loss: 7.9882e-05 - val_mean_absolute_error: 0.0071
# Epoch 13/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.7052e-05 - mean_absolute_error: 0.0059 - val_loss: 7.8637e-05 - val_mean_absolute_error: 0.0072
# Epoch 14/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 5.0200e-05 - mean_absolute_error: 0.0056 - val_loss: 1.4299e-04 - val_mean_absolute_error: 0.0098
# Epoch 15/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 5.7123e-05 - mean_absolute_error: 0.0059 - val_loss: 1.0337e-04 - val_mean_absolute_error: 0.0081
# Epoch 16/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 5.5901e-05 - mean_absolute_error: 0.0059 - val_loss: 2.0228e-04 - val_mean_absolute_error: 0.0120
# Epoch 17/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 6.4512e-05 - mean_absolute_error: 0.0063 - val_loss: 1.0268e-04 - val_mean_absolute_error: 0.0082
# Epoch 18/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.5990e-05 - mean_absolute_error: 0.0069 - val_loss: 6.5578e-05 - val_mean_absolute_error: 0.0064
# Epoch 19/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 7.0273e-05 - mean_absolute_error: 0.0067 - val_loss: 3.1307e-04 - val_mean_absolute_error: 0.0158
# Epoch 20/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.9828e-05 - mean_absolute_error: 0.0061 - val_loss: 3.4423e-04 - val_mean_absolute_error: 0.0167
# Epoch 21/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.1679e-05 - mean_absolute_error: 0.0071 - val_loss: 9.1527e-05 - val_mean_absolute_error: 0.0077
# Epoch 22/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - loss: 5.0292e-05 - mean_absolute_error: 0.0056 - val_loss: 7.5959e-05 - val_mean_absolute_error: 0.0071
# Epoch 23/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.0189e-05 - mean_absolute_error: 0.0061 - val_loss: 1.4139e-04 - val_mean_absolute_error: 0.0098
# Epoch 24/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 5.7876e-05 - mean_absolute_error: 0.0060 - val_loss: 1.0601e-04 - val_mean_absolute_error: 0.0082
# Epoch 25/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.7827e-05 - mean_absolute_error: 0.0060 - val_loss: 8.9967e-05 - val_mean_absolute_error: 0.0076
# Epoch 26/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 8.2704e-05 - mean_absolute_error: 0.0072 - val_loss: 1.0462e-04 - val_mean_absolute_error: 0.0082
# Epoch 27/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - loss: 4.9804e-05 - mean_absolute_error: 0.0056 - val_loss: 1.6743e-04 - val_mean_absolute_error: 0.0110
# Epoch 28/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 7.4390e-05 - mean_absolute_error: 0.0068 - val_loss: 9.4542e-05 - val_mean_absolute_error: 0.0077
# Epoch 29/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.6685e-05 - mean_absolute_error: 0.0053 - val_loss: 6.2462e-05 - val_mean_absolute_error: 0.0062
# Epoch 30/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 4.7204e-05 - mean_absolute_error: 0.0054 - val_loss: 1.4929e-04 - val_mean_absolute_error: 0.0105
# Epoch 31/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 29ms/step - loss: 6.1948e-05 - mean_absolute_error: 0.0062 - val_loss: 1.1846e-04 - val_mean_absolute_error: 0.0089
# Epoch 32/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 5.2699e-05 - mean_absolute_error: 0.0057 - val_loss: 5.8373e-05 - val_mean_absolute_error: 0.0061
# Epoch 33/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 6.4541e-05 - mean_absolute_error: 0.0063 - val_loss: 1.5055e-04 - val_mean_absolute_error: 0.0103
# Epoch 34/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 6.7129e-05 - mean_absolute_error: 0.0065 - val_loss: 1.9753e-04 - val_mean_absolute_error: 0.0120
# Epoch 35/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 32ms/step - loss: 6.6033e-05 - mean_absolute_error: 0.0063 - val_loss: 1.0635e-04 - val_mean_absolute_error: 0.0081
# Epoch 36/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 4.4254e-05 - mean_absolute_error: 0.0052 - val_loss: 2.0988e-04 - val_mean_absolute_error: 0.0125
# Epoch 37/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 5.2083e-05 - mean_absolute_error: 0.0057 - val_loss: 5.2077e-05 - val_mean_absolute_error: 0.0057
# Epoch 38/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 6.6901e-05 - mean_absolute_error: 0.0064 - val_loss: 1.8146e-04 - val_mean_absolute_error: 0.0112
# Epoch 39/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 6.6356e-05 - mean_absolute_error: 0.0064 - val_loss: 2.4334e-04 - val_mean_absolute_error: 0.0132
# Epoch 40/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 4.9462e-05 - mean_absolute_error: 0.0055 - val_loss: 1.0172e-04 - val_mean_absolute_error: 0.0081
# Epoch 41/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 4.6853e-05 - mean_absolute_error: 0.0054 - val_loss: 1.1560e-04 - val_mean_absolute_error: 0.0088
# Epoch 42/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 6.7544e-05 - mean_absolute_error: 0.0064 - val_loss: 1.8163e-04 - val_mean_absolute_error: 0.0114
# Epoch 43/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.4014e-05 - mean_absolute_error: 0.0058 - val_loss: 9.8828e-05 - val_mean_absolute_error: 0.0081
# Epoch 44/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.5856e-05 - mean_absolute_error: 0.0059 - val_loss: 5.9481e-05 - val_mean_absolute_error: 0.0062
# Epoch 45/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 5.1259e-05 - mean_absolute_error: 0.0057 - val_loss: 1.4593e-04 - val_mean_absolute_error: 0.0096
# Epoch 46/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.5996e-05 - mean_absolute_error: 0.0069 - val_loss: 9.2910e-05 - val_mean_absolute_error: 0.0077
# Epoch 47/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.1847e-05 - mean_absolute_error: 0.0062 - val_loss: 9.6276e-05 - val_mean_absolute_error: 0.0076
# Epoch 48/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.3820e-05 - mean_absolute_error: 0.0068 - val_loss: 1.6549e-04 - val_mean_absolute_error: 0.0109
# Epoch 49/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.3489e-05 - mean_absolute_error: 0.0057 - val_loss: 2.7444e-04 - val_mean_absolute_error: 0.0148
# Epoch 50/50
# 50/50 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.4770e-05 - mean_absolute_error: 0.0074 - val_loss: 1.6622e-04 - val_mean_absolute_error: 0.0108
#
# Final model training complete after 50 epochs.

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
final_lstm_predictions = model_final.predict(X_test_final)
final_lstm_predictions_1d = final_lstm_predictions.flatten()
rmse_final_lstm = np.sqrt(mean_squared_error(y_test_final, final_lstm_predictions_1d))
mae_final_lstm = mean_absolute_error(y_test_final, final_lstm_predictions_1d)
print(f"\nFinal Tuned LSTM Model Performance on Test Set:")
print(f"RMSE: {rmse_final_lstm:.4f}")
print(f"MAE: {mae_final_lstm:.4f}")
print("\nComparison with SARIMAX Model:")
sarimax_rmse = 0.0485
sarimax_mae = 0.0415
print(f"SARIMAX RMSE: {sarimax_rmse:.4f}")
print(f"SARIMAX MAE: {sarimax_mae:.4f}")
full_index_for_plot = df_cleaned.index[optimal_sequence_length : ]
index_test_final = full_index_for_plot[train_split_final + val_split_final:]
plt.figure(figsize=(15, 6))
plt.plot(index_test_final, y_test_final, label='Actual Test Data (Normalized)')
plt.plot(index_test_final, final_lstm_predictions_1d, color='red', label='LSTM Predictions (Normalized)')
plt.title('Final Tuned LSTM Model Predictions vs Actuals on Test Set')
plt.xlabel('Date')
plt.ylabel('Electricity Consumption (Normalized)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
#
# Final Tuned LSTM Model Performance on Test Set:
# RMSE: 0.0174
# MAE: 0.0157
#
# Comparison with SARIMAX Model:
# SARIMAX RMSE: 0.0485
# SARIMAX MAE: 0.0415

# %%
import shap
print("SHAP library imported successfully!")
# Out:
# SHAP library imported successfully!

# %%
import numpy as np 
peak_index_in_y_test = np.argmax(y_test_final)
trough_index_in_y_test = np.argmin(y_test_final)
print(f"Index of peak value in y_test_final: {peak_index_in_y_test}")
print(f"Peak value in y_test_final: {y_test_final[peak_index_in_y_test]:.4f}")
print(f"Index of trough value in y_test_final: {trough_index_in_y_test}")
print(f"Trough value in y_test_final: {y_test_final[trough_index_in_y_test]:.4f}")
# Out:
# Index of peak value in y_test_final: 420
# Peak value in y_test_final: 1.0000
# Index of trough value in y_test_final: 20
# Trough value in y_test_final: 0.6601

# %%
X_peak_sample = X_test_final[peak_index_in_y_test:peak_index_in_y_test+1]
X_trough_sample = X_test_final[trough_index_in_y_test:trough_index_in_y_test+1]
print(f"Shape of X_peak_sample: {X_peak_sample.shape}")
print(f"Shape of X_trough_sample: {X_trough_sample.shape}")
# Out:
# Shape of X_peak_sample: (1, 10, 9)
# Shape of X_trough_sample: (1, 10, 9)

# %%
import shap
model_predict = lambda x: model_final.predict(x).flatten()
background_data = shap.sample(X_train_final, 100)
explainer = shap.KernelExplainer(model_predict, background_data)
print("SHAP KernelExplainer created successfully.")
print(f"Background data shape: {background_data.shape}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# SHAP KernelExplainer created successfully.
# Background data shape: (100, 10, 9)

# %%
import shap
import numpy as np
num_features = X_train_final.shape[2]
optimal_sequence_length = best_params['sequence_length']
def model_predict_for_shap(x_2d):
    x_3d = x_2d.reshape(-1, optimal_sequence_length, num_features)
    return model_final.predict(x_3d).flatten()
background_data_reshaped = background_data.reshape(background_data.shape[0], -1)
explainer = shap.KernelExplainer(model_predict_for_shap, background_data_reshaped)
X_peak_sample_reshaped = X_peak_sample.reshape(X_peak_sample.shape[0], -1)
shap_values_peak = explainer.shap_values(X_peak_sample_reshaped)
print("SHAP values for peak sample computed.")
print(f"Shape of SHAP values for peak sample: {shap_values_peak[0].shape}")
# Out:
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step
# 6900/6900 ━━━━━━━━━━━━━━━━━━━━ 41s 6ms/step
# SHAP values for peak sample computed.
# Shape of SHAP values for peak sample: (90,)

# %%
import numpy as np
X_trough_sample_reshaped = X_trough_sample.reshape(X_trough_sample.shape[0], -1)
shap_values_trough = explainer.shap_values(X_trough_sample_reshaped)
print("SHAP values for trough sample computed.")
print(f"Shape of SHAP values for trough sample: {shap_values_trough[0].shape}")
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 6900/6900 ━━━━━━━━━━━━━━━━━━━━ 42s 6ms/step
# SHAP values for trough sample computed.
# Shape of SHAP values for trough sample: (90,)

# %%
feature_names = df_cleaned.drop(columns=['electricity_consumption']).columns.tolist()
print("Feature names:")
print(feature_names)
print(f"Number of features: {len(feature_names)}")
# Out:
# Feature names:
# ['year', 'month_of_year', 'day_of_month', 'day_of_week', 'electricity_consumption_lag_1', 'electricity_consumption_lag_2', 'electricity_consumption_lag_3', 'electricity_consumption_lag_4']
# Number of features: 8

# %%
feature_names_base = df_cleaned.columns.tolist()
optimal_sequence_length = best_params['sequence_length']
feature_names_for_shap = []
for i in range(optimal_sequence_length):
    for name in feature_names_base:
        feature_names_for_shap.append(f'{name}_t-{optimal_sequence_length - 1 - i}')
print("Generated feature names for SHAP (first 10 and last 10):")
print(feature_names_for_shap[:10])
print('...')
print(feature_names_for_shap[-10:])
print(f"Total number of SHAP feature names: {len(feature_names_for_shap)}")
# Out:
# Generated feature names for SHAP (first 10 and last 10):
# ['electricity_consumption_t-9', 'year_t-9', 'month_of_year_t-9', 'day_of_month_t-9', 'day_of_week_t-9', 'electricity_consumption_lag_1_t-9', 'electricity_consumption_lag_2_t-9', 'electricity_consumption_lag_3_t-9', 'electricity_consumption_lag_4_t-9', 'electricity_consumption_t-8']
# ...
# ['electricity_consumption_lag_4_t-1', 'electricity_consumption_t-0', 'year_t-0', 'month_of_year_t-0', 'day_of_month_t-0', 'day_of_week_t-0', 'electricity_consumption_lag_1_t-0', 'electricity_consumption_lag_2_t-0', 'electricity_consumption_lag_3_t-0', 'electricity_consumption_lag_4_t-0']
# Total number of SHAP feature names: 90

# %%
shap.initjs()
expected_value = explainer.expected_value
print(f"Model's expected value (base value): {expected_value:.4f}")
print("\nSHAP Force Plot for Peak Prediction:")
shap.force_plot(expected_value, shap_values_peak[0], X_peak_sample_reshaped[0], feature_names=feature_names_for_shap)
print("\nSHAP Force Plot for Trough Prediction:")
shap.force_plot(expected_value, shap_values_trough[0], X_trough_sample_reshaped[0], feature_names=feature_names_for_shap)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221:(e,t,n)=>{"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.0"},247:(e,t,n)=>{"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&n ...
# Model's expected value (base value): 0.2875
#
# SHAP Force Plot for Peak Prediction:
#
# SHAP Force Plot for Trough Prediction:
# <div id='iYUZXOBCYRLKSMWCW1NGS'>
# <div style='color: #900; text-align: center;'>
#   <b>Visualization omitted, Javascript library not loaded!</b><br>
#   Have you run `initjs()` in this notebook? If this notebook was from another
#   user you must also trust this notebook (File -> Trust notebook). If you are viewing
#   this notebook on github the Javascript has been stripped for security. If you are using
#   JupyterLab this error is because a JupyterLab extension has not yet been written.
# </div></div>
#  <script>
#    if (window.SHAP) SHAP.ReactDom.render(
#     SHAP.React.createElement(SHAP.AdditiveForceVisualizer, {"outNames": ["f(x)"], "baseValue": 0.287485474999994, "outValue": 0.690889835357666, "link": "identity", "featureNames": ["electricity_consumption_t-9", "year_t-9", "month_of_year_t-9", "day_of_month_t-9", "day_of_week_t-9", "electricity_consumption_lag_1_t-9", "electricity_consumption_lag_2_t-9", "electricity_consumption_lag_3_t-9", "electricity_consumption_lag_4_t-9", "electricity_consumption_t-8", "year_t-8", "month_of_year_t-8", "day_of_month_t-8", "day_of_week_t-8", "electricity_consumption_lag_1_t-8", "electricity_consumption_lag_2_t-8", "electricity_consumption_lag_3_t-8", "electricity_consumption_lag_4_t-8", "electricity_consumption_t-7", "year_t-7", "month_of_year_t-7", "day_of_month_t-7", "day_of_week_t-7", "electricity_consumption_lag_1_t-7", "electricity_consumption_lag_2_t-7", "electricity_consumption_lag_3_t-7", "electricity_consumption_lag_4_t-7", "electricity_consumption_t-6", "year_t-6", "month_of_year_t-6", "day_of_month_t-6", "day_of_week_t-6", "electricity_consumption_lag_1_t-6", "electricity_consumption_lag_2_t-6", "electricity_consumption_lag_3_t-6", "electricity_consumption_lag_4_t-6", "electricity_consumption_t-5", "year_t-5", "month_of_year_t-5", "day_of_month_t-5", "day_of_week_t-5", "electricity_consumption_lag_1_t-5", "electricity_consumption_lag_2_t-5", "electricity_consumption_lag_3_t-5", "electricity_consumption_lag_4_t-5", "electricity_consumption_t-4", "year_t-4", "month_of_year_t-4", "day_of_month_t-4", "day_of_week_t-4", "electricity_consumption_lag_1_t-4", "electricity_consumption_lag_2_t-4", "electricity_consumption_lag_3_t-4", "electricity_consumption_lag_4_t-4", "electricity_consumption_t-3", "year_t-3", "month_of_year_t-3", "day_of_month_t-3", "day_of_week_t-3", "electricity_consumption_lag_1_t-3", "electricity_consumption_lag_2_t-3", "electricity_consumption_lag_3_t-3", "electricity_consumption_lag_4_t-3", "electricity_consumption_t-2", "year_t-2", "month_of_year_t-2", "day_of_month_t-2", "day_of_week_t-2", "electricity_consumption_lag_1_t-2", "electricity_consumption_lag_2_t-2", "electricity_consumption_lag_3_t-2", "electricity_consumption_lag_4_t-2", "electricity_consumption_t-1", "year_t-1", "month_of_year_t-1", "day_of_month_t-1", "day_of_week_t-1", "electricity_consumption_lag_1_t-1", "electricity_consumption_lag_2_t-1", "electricity_consumption_lag_3_t-1", "electricity_consumption_lag_4_t-1", "electricity_consumption_t-0", "year_t-0", "month_of_year_t-0", "day_of_month_t-0", "day_of_week_t-0", "electricity_consumption_lag_1_t-0", "electricity_consumption_lag_2_t-0", "electricity_consumption_lag_3_t-0", "electricity_consumption_lag_4_t-0"], "features": {"72": {"effect": 0.011310818886973552, "value": 0.6847290640394093}, "73": {"effect": 0.007081962027657901, "value": 0.8139534883720927}, "77": {"effect": 0.010949429466632788, "value": 0.6880131362889985}, "78": {"effect": 0.003075292121094919, "value": 0.7044334975369457}, "81": {"effect": 0.11995798445776205, "value": 0.6781609195402307}, "82": {"effect": 0.04633219269966171, "value": 0.8139534883720927}, "86": {"effect": 0.09068356565404691, "value": 0.6847290640394093}, "87": {"effect": 0.05568492171226379, "value": 0.6880131362889985}, "88": {"effect": 0.03701142613493704, "value": 0.7044334975369457}, "89": {"effect": 0.021316767196641394, "value": 0.7027914614121515}}, "plot_cmap": "RdBu", "labelMargin": 20}),
#     document.getElementById('iYUZXOBCYRLKSMWCW1NGS')
#   );
# </script>
